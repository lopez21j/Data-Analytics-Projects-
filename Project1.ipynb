# %% [markdown]
# <a href="https://colab.research.google.com/github/lopez21j/Data-Analytics-Founations-/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
missing_values =("n/a", "na", "s")

# %%
data = pd.read_csv("https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv",na_values=missing_values)

# %%
data['School DBN'].is_unique
# Out:
# False

# %% [markdown]
# Comparing the High School regents Grades from the Bronx to those of Manhattan

# %% [markdown]
# # DATA CLEANING PART

# %%
df2= data[['School DBN','School Level','Regents Exam','Year','Mean Score', 'Percent Scoring 65 or Above', 'Number Scoring 65 or Above', 'Number Scoring Below 65']].fillna(0)

# %%
df2
# Out:
#        School DBN School Level                 Regents Exam  Year  Mean Score  \
# 0          01M034          K-8          Common Core Algebra  2017         0.0
# 1          01M034          K-8           Living Environment  2015        77.9
# 2          01M034          K-8           Living Environment  2016        74.0
# 3          01M140          K-8          Common Core Algebra  2016         0.0
# 4          01M140          K-8          Common Core Algebra  2017         0.0
# ...           ...          ...                          ...   ...         ...
# 212326     84X717          K-8           Living Environment  2016         0.0
# 212327     84X717          K-8           Living Environment  2016         0.0
# 212328     84X717          K-8           Living Environment  2017         0.0
# 212329     84X717          K-8           Living Environment  2017         0.0
# 212330     84X717          K-8  U.S. History and Government  2015         0.0
#
# ...

# %%
df3=df2.set_index('School DBN').filter(like='M', axis=0)## filtered the new data set to show only the results for Manhattan schools

# %%
df3
# Out:
#                School Level                 Regents Exam  Year  Mean Score  \
# School DBN
# 01M034                  K-8          Common Core Algebra  2017         0.0
# 01M034                  K-8           Living Environment  2015        77.9
# 01M034                  K-8           Living Environment  2016        74.0
# 01M140                  K-8          Common Core Algebra  2016         0.0
# 01M140                  K-8          Common Core Algebra  2017         0.0
# ...                     ...                          ...   ...         ...
# 84M726      K-12 all grades  U.S. History and Government  2017         0.0
# 84M726      K-12 all grades  U.S. History and Government  2017        74.9
# 84M726      K-12 all grades  U.S. History and Government  2017        84.9
# 84M726      K-12 all grades  U.S. History and Government  2017         0.0
# 84M726      K-12 all grades  U.S. History and Government  2017         0.0
#
# ...

# %%
df_M= df3[(df3['School Level'] == 'High school') & (df3['Year'] == 2017) & (df3['Regents Exam']== 'Common Core English')]##filter the school level by High Shool, the most recent year 2017 and by the English regents

# %%
df_M
# Out:
#            School Level         Regents Exam  Year  Mean Score  \
# School DBN
# 01M292      High school  Common Core English  2017        77.2
# 01M448      High school  Common Core English  2017        73.1
# 01M458      High school  Common Core English  2017        64.5
# 01M509      High school  Common Core English  2017        67.5
# 01M515      High school  Common Core English  2017        74.3
# ...                 ...                  ...   ...         ...
# 84M522      High school  Common Core English  2017         0.0
# 84M707      High school  Common Core English  2017         0.0
# 84M707      High school  Common Core English  2017        70.3
# 84M707      High school  Common Core English  2017        70.3
# 84M707      High school  Common Core English  2017         0.0
#
#             Percent Scoring 65 or Above  Number Scoring 65 or Above  \
# School DBN
# 01M292                             92.7                        38.0
# ...

# %%
df_M2= df3[(df3['School Level'] == 'High school') & (df3['Year'] == 2017) & (df3['Regents Exam']== 'Common Core Algebra')]

# %%
df_M2 ## data frame that shows Scores for Common Core Algebra in the Borough of Manhattan
# Out:
#            School Level         Regents Exam  Year  Mean Score  \
# School DBN
# 01M292      High school  Common Core Algebra  2017        67.5
# 01M448      High school  Common Core Algebra  2017        72.9
# 01M458      High school  Common Core Algebra  2017        49.3
# 01M509      High school  Common Core Algebra  2017        59.9
# 01M515      High school  Common Core Algebra  2017        77.0
# ...                 ...                  ...   ...         ...
# 84M522      High school  Common Core Algebra  2017        63.2
# 84M522      High school  Common Core Algebra  2017         0.0
# 84M707      High school  Common Core Algebra  2017         0.0
# 84M707      High school  Common Core Algebra  2017        71.9
# 84M707      High school  Common Core Algebra  2017         0.0
#
#             Percent Scoring 65 or Above  Number Scoring 65 or Above  \
# School DBN
# 01M292                             71.7                        38.0
# ...

# %%
duplicate = df_M[df_M.duplicated()] ## assigned a variable named duplicated to looked for all the duplicated in df_M

# %%
duplicate
# Out:
#            School Level         Regents Exam  Year  Mean Score  \
# School DBN
# 01M696      High school  Common Core English  2017         0.0
# 02M394      High school  Common Core English  2017        75.3
# 02M427      High school  Common Core English  2017         0.0
# 02M427      High school  Common Core English  2017         0.0
# 02M438      High school  Common Core English  2017         0.0
# ...                 ...                  ...   ...         ...
# 84M433      High school  Common Core English  2017         0.0
# 84M522      High school  Common Core English  2017         0.0
# 84M522      High school  Common Core English  2017         0.0
# 84M707      High school  Common Core English  2017         0.0
# 84M707      High school  Common Core English  2017         0.0
#
#             Percent Scoring 65 or Above  Number Scoring 65 or Above  \
# School DBN
# 01M696                              0.0                         0.0
# ...

# %%
dfM = df_M[df_M.loc[:]!=0].dropna()## dropped all the values with 0

# %%
dfM
# Out:
#            School Level         Regents Exam  Year  Mean Score  \
# School DBN
# 01M292      High school  Common Core English  2017        77.2
# 01M448      High school  Common Core English  2017        73.1
# 01M458      High school  Common Core English  2017        64.5
# 01M509      High school  Common Core English  2017        67.5
# 01M515      High school  Common Core English  2017        74.3
# ...                 ...                  ...   ...         ...
# 84M433      High school  Common Core English  2017        61.3
# 84M433      High school  Common Core English  2017        63.7
# 84M522      High school  Common Core English  2017        71.8
# 84M707      High school  Common Core English  2017        70.3
# 84M707      High school  Common Core English  2017        70.3
#
#             Percent Scoring 65 or Above  Number Scoring 65 or Above  \
# School DBN
# 01M292                             92.7                        38.0
# ...

# %%
duplicate1 = df_M2[df_M2.duplicated()]

# %%
duplicate1
# Out:
#            School Level         Regents Exam  Year  Mean Score  \
# School DBN
# 02M303      High school  Common Core Algebra  2017         0.0
# 02M313      High school  Common Core Algebra  2017         0.0
# 02M534      High school  Common Core Algebra  2017         0.0
# 02M560      High school  Common Core Algebra  2017         0.0
# 03M479      High school  Common Core Algebra  2017         0.0
# ...                 ...                  ...   ...         ...
# 84M433      High school  Common Core Algebra  2017         0.0
# 84M522      High school  Common Core Algebra  2017         0.0
# 84M522      High school  Common Core Algebra  2017         0.0
# 84M707      High school  Common Core Algebra  2017         0.0
# 84M707      High school  Common Core Algebra  2017         0.0
#
#             Percent Scoring 65 or Above  Number Scoring 65 or Above  \
# School DBN
# 02M303                              0.0                         0.0
# ...

# %%
dfM2= df_M2[df_M2.loc[:]!=0].dropna()## dropped all the values with 0 for the data showing the HS scores for Common Core Algebra

# %%
dfM2
# Out:
#            School Level         Regents Exam  Year  Mean Score  \
# School DBN
# 01M292      High school  Common Core Algebra  2017        67.5
# 01M448      High school  Common Core Algebra  2017        72.9
# 01M509      High school  Common Core Algebra  2017        59.9
# 01M515      High school  Common Core Algebra  2017        77.0
# 01M650      High school  Common Core Algebra  2017        64.1
# ...                 ...                  ...   ...         ...
# 84M433      High school  Common Core Algebra  2017        59.0
# 84M433      High school  Common Core Algebra  2017        61.4
# 84M522      High school  Common Core Algebra  2017        60.5
# 84M522      High school  Common Core Algebra  2017        63.2
# 84M707      High school  Common Core Algebra  2017        71.9
#
#             Percent Scoring 65 or Above  Number Scoring 65 or Above  \
# School DBN
# 01M292                             71.7                        38.0
# ...

# %% [markdown]
# # Bronx Filtered Data

# %%
df4=df2.set_index('School DBN').filter(like='X', axis=0).fillna(0) ## filtered only the schools in the Bronx

# %%
df4
# Out:
#            School Level                 Regents Exam  Year  Mean Score  \
# School DBN
# 10X504      High school          Common Core Algebra  2015         0.0
# 07X029              K-8          Common Core Algebra  2015        65.0
# 07X029              K-8          Common Core Algebra  2016        66.5
# 07X029              K-8          Common Core Algebra  2017        61.3
# 07X029              K-8           Living Environment  2015        67.8
# ...                 ...                          ...   ...         ...
# 84X717              K-8           Living Environment  2016         0.0
# 84X717              K-8           Living Environment  2016         0.0
# 84X717              K-8           Living Environment  2017         0.0
# 84X717              K-8           Living Environment  2017         0.0
# 84X717              K-8  U.S. History and Government  2015         0.0
#
#             Percent Scoring 65 or Above  Number Scoring 65 or Above  \
# School DBN
# ...

# %%
df_BX = df4[(df4['School Level'] == 'High school') & (df4['Year'] == 2017)& (df4['Regents Exam']== 'Common Core English') ]

# %%
df_BX ## dataframe that shows only the High School scores in the Bronx for Common Core English for the year 2017
# Out:
#            School Level         Regents Exam  Year  Mean Score  \
# School DBN
# 07X259      High school  Common Core English  2017        64.6
# 07X334      High school  Common Core English  2017        60.2
# 07X379      High school  Common Core English  2017        53.5
# 07X381      High school  Common Core English  2017        63.1
# 07X427      High school  Common Core English  2017        60.5
# ...                 ...                  ...   ...         ...
# 84X553      High school  Common Core English  2017        75.5
# 84X553      High school  Common Core English  2017        70.9
# 84X553      High school  Common Core English  2017        69.9
# 84X553      High school  Common Core English  2017         0.0
# 84X553      High school  Common Core English  2017         0.0
#
#             Percent Scoring 65 or Above  Number Scoring 65 or Above  \
# School DBN
# 07X259                             63.8                        90.0
# ...

# %%
df_BX1 = df4[(df4['School Level'] == 'High school') & (df4['Year'] == 2017)& (df4['Regents Exam']== 'Common Core Algebra') ]

# %%
df_BX1 ## this data frame shows only the High School scores in the Bronx for Common Core Algebra for year 2017
# Out:
#            School Level         Regents Exam  Year  Mean Score  \
# School DBN
# 07X259      High school  Common Core Algebra  2017        59.7
# 07X379      High school  Common Core Algebra  2017        59.6
# 07X381      High school  Common Core Algebra  2017        61.5
# 07X456      High school  Common Core Algebra  2017        57.2
# 07X473      High school  Common Core Algebra  2017        61.0
# ...                 ...                  ...   ...         ...
# 84X553      High school  Common Core Algebra  2017        66.3
# 84X553      High school  Common Core Algebra  2017         0.0
# 84X553      High school  Common Core Algebra  2017         0.0
# 84X581      High school  Common Core Algebra  2017         0.0
# 84X581      High school  Common Core Algebra  2017         0.0
#
#             Percent Scoring 65 or Above  Number Scoring 65 or Above  \
# School DBN
# 07X259                             41.8                       100.0
# ...

# %%
duplicate = df_BX[df_BX.duplicated()]

# %%
duplicate
# Out:
#            School Level         Regents Exam  Year  Mean Score  \
# School DBN
# 08X507      High school  Common Core English  2017         0.0
# 84X429      High school  Common Core English  2017         0.0
# 08X507      High school  Common Core English  2017         0.0
# 08X507      High school  Common Core English  2017         0.0
# 07X259      High school  Common Core English  2017        70.2
# ...                 ...                  ...   ...         ...
# 84X539      High school  Common Core English  2017         0.0
# 84X539      High school  Common Core English  2017         0.0
# 84X539      High school  Common Core English  2017         0.0
# 84X553      High school  Common Core English  2017         0.0
# 84X553      High school  Common Core English  2017         0.0
#
#             Percent Scoring 65 or Above  Number Scoring 65 or Above  \
# School DBN
# 08X507                              0.0                         0.0
# ...

# %%
dfBX = df_BX[df_BX.loc[:]!=0].dropna() ## dropped all the 0's

# %%
dfBX
# Out:
#            School Level         Regents Exam  Year  Mean Score  \
# School DBN
# 07X259      High school  Common Core English  2017        64.6
# 07X334      High school  Common Core English  2017        60.2
# 07X379      High school  Common Core English  2017        53.5
# 07X381      High school  Common Core English  2017        63.1
# 07X427      High school  Common Core English  2017        60.5
# ...                 ...                  ...   ...         ...
# 84X539      High school  Common Core English  2017        61.2
# 84X539      High school  Common Core English  2017        59.6
# 84X553      High school  Common Core English  2017        75.5
# 84X553      High school  Common Core English  2017        70.9
# 84X553      High school  Common Core English  2017        69.9
#
#             Percent Scoring 65 or Above  Number Scoring 65 or Above  \
# School DBN
# 07X259                             63.8                        90.0
# ...

# %%
duplicate2 = df_BX1[df_BX1.duplicated()]

# %%
duplicate2
# Out:
#            School Level         Regents Exam  Year  Mean Score  \
# School DBN
# 08X507      High school  Common Core Algebra  2017         0.0
# 08X507      High school  Common Core Algebra  2017         0.0
# 07X381      High school  Common Core Algebra  2017         0.0
# 07X381      High school  Common Core Algebra  2017         0.0
# 08X377      High school  Common Core Algebra  2017         0.0
# ...                 ...                  ...   ...         ...
# 84X539      High school  Common Core Algebra  2017         0.0
# 84X553      High school  Common Core Algebra  2017         0.0
# 84X553      High school  Common Core Algebra  2017         0.0
# 84X581      High school  Common Core Algebra  2017         0.0
# 84X581      High school  Common Core Algebra  2017         0.0
#
#             Percent Scoring 65 or Above  Number Scoring 65 or Above  \
# School DBN
# 08X507                              0.0                         0.0
# ...

# %%
dfBX1= df_BX1[df_BX1.loc[:]!=0].dropna()

# %%
dfBX1 ## BX Common Core Algebra scores no duplicates and no zeros

# %% [markdown]
# # Visualization Part

# %% [markdown]
# Visuals Representing the Common Core English Regents scores for Bronx and Manhattan. Bronx=Blue Manhattan=Purple

# %%
sns.set(style='dark',)
data = dfM['Mean Score']
plot = sns.distplot(data,color='purple')

plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data = dfBX['Mean Score']
plot = sns.distplot(data,color='blue')

plt.show() ## This shows the
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Visuals representing the Regents results for Common Core Algebra. Bronx=Blue and Manhattan=Purple

# %%
sns.set(style='dark',)
data = dfM2['Mean Score']
plot = sns.distplot(data,color='purple')

plt.show() ## Math scores for HS students in Manhattan
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data = dfBX1['Mean Score']
plot = sns.distplot(data,color='blue')

plt.show() ## Math scores for HS students in the Bronx
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Stats

# %% [markdown]
# # Stats of the English Regents scores between Manhattan and Bronx

# %%
dfBX

# %%
dfBX['Mean Score'].mean()## the average score for English regents for students in the Bronx
# Out:
# 63.89890610756609

# %%
dfM['Mean Score'].mean() ## the average score for the English regents for students in Manhattan
# Out:
# 69.96140552995392

# %%
dfBX['Number Scoring 65 or Above'].max()
# Out:
# 724.0

# %%
dfM['Number Scoring 65 or Above'].max()
# Out:
# 823.0

# %%
dfBX['Number Scoring Below 65'].max()
# Out:
# 170.0

# %%
dfM['Number Scoring Below 65'].max()
# Out:
# 87.0

# %%
dfBX3_sum = dfBX['Number Scoring Below 65'].sum() ## the total number of studentsin the Bronx that scored below 65 in the English Regents 
print(dfBX3_sum)
# Out:
# 21415.0

# %%
dfM4_sum = dfM['Number Scoring Below 65'].sum() ## the total number of students in Manhattan that scored below 65 in the English Regents 
print(dfM4_sum)
# Out:
# 11474.0

# %% [markdown]
# ## Common Core Algebra Stats between the Bronx and Manhattan

# %%
dfBX1

# %%
dfBX1['Mean Score'].mean() ## Average score for Algebra Regents in the Bronx
# Out:
# 63.10406427221172

# %%
dfM2['Mean Score'].mean() ## Average score for Algebra Regents in Manhattan
# Out:
# 67.05446009389672

# %%
dfBX2_sum = dfBX1['Number Scoring 65 or Above'].sum() ## the total number of Bronx students that scored 65 or above 
print(dfBX2_sum)
# Out:
# 46939.0

# %%
dfM3_sum =dfM2['Number Scoring 65 or Above'].sum() ## the total number of Bronx students that scored 65 or above 
print(dfM3_sum)
# Out:
# 44336.0

# %% [markdown]
# ### Comparing the number of HS students that received a score below 65 in the Algebra Regents for year 2017

# %%
dfBX1['Number Scoring Below 65'].max() ##More Kids scored a 65 or below in the Bronx
# Out:
# 304.0

# %%
dfM2['Number Scoring Below 65'].max() ##Manhattan
# Out:
# 172.0

# %%
dfBX1_sum = dfBX1['Number Scoring Below 65'].sum() ## the total number of Bronx students that scored below 65
print(dfBX1_sum)
# Out:
# 39032.0

# %%
dfM2_sum = dfM2['Number Scoring Below 65'].sum() ## the total number Manhattan students that scored below 65
print(dfM2_sum)
# Out:
# 23294.0

# %% [markdown]
# #Conclusion

# %% [markdown]
# The data was used to compare the Math and English Regent scores for High School students in the Bronx and Manhattan. I used 2017 as the most recent year. Based on the stats and the distribution plot chart I was able to conclude that there are some differences between the scores from the Bronx and Manhanttan. Although the difference is some cases was not that great we can conclude that students in Manhattan scored higher than students in the Bronx. The data also indicated that more students in the Bronx scored 65 or below in both the Math and English regents than students in Manhattan.
